# %% [markdown]
# # Some theory
# For single dimensional spaces, the mean distance is calculated through the following formula
#
# \begin{equation*}
# x^2-(a+b)x+\frac{a^2+b^2}{2}
# \end{equation*}
# where a, b is the start and the end of the range respectivly, and x is the

# %%
# make src visible
import sys
sys.path.insert(0, '../src')

import numpy as np
import matplotlib.pyplot as plt

import bin_exploration

# %%
sample_size = 1000000
points = np.random.uniform(size=sample_size)

plt.figure()
plt.hist(points, bins=40, rwidth=0.5)
plt.title('Distribution of {} samples'.format(sample_size))
plt.xlabel('Space')
plt.ylabel('Count')
plt.grid(True)
plt.show()
